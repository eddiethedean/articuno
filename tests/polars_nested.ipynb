# %%
# Pandas Nested Inference Example
import pandas as pd
from articuno import df_to_pydantic, generate_class_code

# %%
df = pd.DataFrame({
    "info": [{"x": 1}, {"x": 2}],
    "label": ["yes", "no"]
})
models = df_to_pydantic(df)
print(models[0])
# Out:
# info=AutoPandasModel_0_Nested(x=1) label='yes'

# %%
Model = models[0].__class__
print(generate_class_code(Model))
# Out:
# /Users/odosmatthews/Documents/coding/articuno/.venv/lib/python3.9/site-packages/pydantic/json_schema.py:2324: PydanticJsonSchemaWarning: Default value 1 is not JSON serializable; excluding default from JSON schema [non-serializable-default]
#   warnings.warn(message, PydanticJsonSchemaWarning)
# # generated by datamodel-codegen:
# #   filename:  schema.json
# #   timestamp: 2025-07-06T16:11:49+00:00
#
# from __future__ import annotations
#
# from typing import Optional
#
# from pydantic import BaseModel, Field
#
#
# class AutoPandasModel0Nested(BaseModel):
#     x: Optional[int] = Field(None, title='X')
#
#
# class AutoPandasModel(BaseModel):
#     info: Optional[AutoPandasModel0Nested] = Field(
#         default_factory=lambda: AutoPandasModel0Nested.parse_obj({'x': 1})
#     )
#     label: Optional[str] = Field('yes', title='Label')
